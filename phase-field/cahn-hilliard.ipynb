# %% [markdown]
# ```
# # Author: Elvis do A. Soares, @elvissoares, 2022-03-25
# # Adapted by: sabrina.sicolo@tu-darmstadt.de, 2025-03
# ```

# %%
# === EXECUTE THIS CELL ===

import numpy as np
from scipy.fft import fft2, ifft2
import sympy as sp
from sympy import *

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import animation
from matplotlib.animation import PillowWriter
from IPython.display import display, Image

import pandas as pd
import seaborn as sns
sns.set_context("talk")


def cahn_hilliard(c0, M, kappa, W, noise, Nsteps, rng_seed):
    # === Fixed parameters ===
    N = 64
    dx = dy = 1.0
    L = N * dx
    dt = 0.1
    energy_interval = 50
    snapshot_base = 375

    # === Initialization ===
    rng = np.random.default_rng(rng_seed)
    c = np.empty((Nsteps, N, N), dtype=np.float32)
    c[0] = c0 + noise * rng.standard_normal(size=(N, N))

    # FFT wavenumbers
    kx = np.fft.fftfreq(N, d=dx) * 2 * np.pi
    ky = np.fft.fftfreq(N, d=dy) * 2 * np.pi
    KX, KY = np.meshgrid(kx, ky, indexing='ij')
    K2 = KX**2 + KY**2

    # Dealiasing mask (2/3 rule)
    kmax_dealias = kx.max() * 2.0 / 3.0
    dealias = (np.abs(KX) < kmax_dealias) & (np.abs(KY) < kmax_dealias)

    # === Free energy derivative ===
    def dfdc(c):
        return 2 * W * (c * (1 - c)**2 - (1 - c) * c**2)

    # === Compute total free energy ===
    def compute_energy(c):
        f_bulk = W * c**2 * (1 - c)**2
        grad_c_x = np.gradient(c, dx, axis=0)
        grad_c_y = np.gradient(c, dy, axis=1)
        grad_energy = 0.5 * kappa * (grad_c_x**2 + grad_c_y**2)
        return np.sum(f_bulk + grad_energy) * dx * dy

    # === Spectral buffer ===
    c_hat = fft2(c[0])
    dfdc_hat = np.empty((N, N), dtype=np.complex64)

    # === Energy tracking ===
    energy_records = []

    # === Precompute snapshot steps ===
    snapshot_steps = [0]
    step = snapshot_base
    while step < Nsteps:
        snapshot_steps.append(step)
        step *= 2

    # === Time-stepping loop (Cahn-Hilliard solver) ===
    for i in range(Nsteps):
        if i > 0:
            dfdc_hat[:] = fft2(dfdc(c[i - 1]))
            dfdc_hat *= dealias
            c_hat[:] = (c_hat - dt * K2 * M * dfdc_hat) / (1 + dt * M * kappa * K2**2)
            c[i] = ifft2(c_hat).real

        # Energy tracking every energy_interval steps
        if i % energy_interval == 0:
            energy = compute_energy(c[i])
            energy_records.append({'step': i, 'time': i * dt, 'energy': energy})

        # Plot snapshot if it's a scheduled snapshot step
        if i in snapshot_steps:
            plt.figure(figsize=(2.5, 2.5))
            plt.imshow(c[i], cmap='plasma', vmin=0.0, vmax=1.0)
            plt.title(f'c0={c0}, Step {i}')
            plt.axis('off')
            plt.tight_layout()
            plt.show()

    # === Convert energy records to DataFrame ===
    energy_df = pd.DataFrame(energy_records)

    # === Mass conservation sanity check ===
    final_mass = c[-1].sum() * dx**2 / L**2
    mass_error = np.abs(c[-1].sum() - c[0].sum()) / c[0].sum()
    print(f"\nFinal mass = {final_mass:.3f} ± {mass_error:.1e}")
    
    sns.lineplot(x=energy_df["step"], y=energy_df["energy"]/N**2)
    plt.xlabel('Step')
    plt.ylabel('Free Energy')
    plt.grid(alpha=0.5)
    plt.tight_layout()
    plt.show()

    return

# %% [markdown]
# ### What are we doing? (technical explanation)
#
# This program solves the Cahn–Hilliard phase-field equation with a spectral semi-implicit method using Fourier transforms and periodic boundary conditions.
# The Fast Fourier Transform (FFT) is used to solve partial differential equations (PDEs) efficiently in Fourier space.
#
# The Cahn–Hilliard equation contains fourth-order spatial derivatives like the Laplacian of the Laplacian ($\nabla^4$ c), which are computationally expensive to compute with finite differences.
#
# - The Laplacian $\nabla^2$ becomes simple in Fourier space:
#   $$
#   \mathcal{F}[\nabla^2 c] = -k^2 \cdot \hat{c}(k)
#   $$
#
# - The Cahn–Hilliard equation:
#   $$
#   \frac{\partial c}{\partial t} = M \nabla^2 \left( \frac{\delta F}{\delta c} \right)
#   $$
#   becomes algebraic after FFT:
#   $$
#   \hat{c}(k, t + \Delta t) = \frac{\hat{c}(k, t) - \Delta t \cdot M \cdot k^2 \cdot \widehat{\delta F/\delta c}}{1 + \Delta t \cdot M \cdot \kappa \cdot k^4}
#   $$
#
# - This avoids expensive numerical differentiation and allows semi-implicit time integration.
#
# In the code snippet:
# ```python
# c_hat = fft2(c[0])
# ...
# dfdc_hat[:] = fft2(dfdc(c[i - 1]))
# ...
# c_hat[:] = (c_hat - dt * K2 * M * dfdc_hat) / (1 + dt * M * kappa * K2**2)
# c[i] = ifft2(c_hat).real
# ```
#
# - `c[i]` is your real-space concentration field at time step `i`.
#
# - `c_hat` is the representation of that field in Fourier space.
#
# You obtain it via:
# ```python
# c_hat = fft2(c[0])
# ```
#
# This uses a 2D Fast Fourier Transform to convert the real-space field `c[0]` into its frequency components.
#
# The spectral method we’re using evolves `c` in Fourier space, where differential operators like $\nabla^2$ and $\nabla^4$ become algebraic (just multiplications by $-k^2$ or $k^4$). That means you don’t need finite-difference stencils.
#
# So instead of updating `c` directly in real space, you update `c_hat` in Fourier space like this:
# ```python
# c_hat = (c_hat - dt * K2 * M * dfdc_hat) / (1 + dt * M * kappa * K2**2)
# ```
#
# Then you transform it back:
# ```python
# c[i] = ifft2(c_hat).real
# ```
#
# Think of `c_hat` as a set of "wave amplitudes" that describe how much of each spatial frequency is present in the concentration pattern.
#
# You evolve those amplitudes efficiently in time, and at each step, convert them back to real-space to see what the concentration field looks like.
#
# Let me know if you want a visualization of `c` vs. `c_hat` to make this more intuitive!

# %% [markdown]
# # Exercise: Cahn-Hilliard and Spinodal Decomposition
#
# The free energy density is coded as:
# $$
# f(c) = Wc^2(1-c)^2,
# $$
# where $0 \leq c \leq 1$.
#
# #### Task a
# In the next cell, write the Python expression for the free energy density.
#
# - Multiplication in Python is written with `*`,
#
# - Powers (exponents) are written with `**`,
#
# - Use parentheses `()` where needed.

# %%
def f_c(W, c):
    return W * c**2 * (1 - c)**2

# %% [markdown]
# #### Task b
#
# Run the code snippet below to visualize the free energy density as a function of the concentration.
# You should recognize the characteristic shape of this curve from theory.
#
# - Identify the stationary points.
# - Locate the inflection points.

# %%
# Parameters
W = 1.0  # Energy parameter

# Create 200 equally spaced concentration values from 0 to 1
c = np.linspace(0, 1, 200)

# Plot using seaborn styling
plt.plot(c, f_c(W,c), color='blue')

# Labels and title
plt.xlabel('Concentration $c$')
plt.ylabel('Free Energy Density $f(c)$')

plt.grid(alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Cross-check your analysis by executing the following snippet:

# %%
# Define symbols
c, W = sp.symbols('c W', real=True)

# First and second derivatives
df_dc = sp.diff(f_c(W,c), c)
d2f_dc2 = sp.diff(df_dc, c)

# Solve for stationary points (df/dc = 0)
stationary_points = sp.solve(df_dc, c)
print(f"Stationary points = {sp.N(stationary_points[0]):.2f}, {sp.N(stationary_points[1]):.2f} and {sp.N(stationary_points[2]):.2f}")

# Solve for inflection points (d²f/dc² = 0)
inflection_points = sp.solve(d2f_dc2, c)
print(f"Inflection points = {sp.N(inflection_points[0]):.2f} and {sp.N(inflection_points[1]):.2f}")
# Out:
# Stationary points = 0.00, 0.50 and 1.00
# Inflection points = 0.21 and 0.79

# %% [markdown]
# #### Task c
# Run the following program for various initial concentrations $c_0 = 0.5, 0.6, 0.7$, using a mobility of $0.5$ and a gradient coefficient of $0.6$, for $50000$ timesteps.
#
# The simulation produces snapshots showing the time evolution of the microstructure and a final plot of the free energy evolution over time.
#
# For each simulation, compare the initial energy value to the free energy density curve you plotted at the beginning.
# Does the initial energy agree with your expectations based on the free energy density?
#
# **Hint:** To avoid overwriting your previous results, duplicate the relevant code cells and update the initial concentration value in each copy. This allows you to run multiple simulations sequentially and compare the outcomes.

# %%
# === System-specific Parameters ===
c0 = 0.5                # Initial concentration
M = 0.5                 # Mobility
kappa = 0.6             # Gradient coefficient
W = 1.0                 # Bulk free energy strength
noise = 0.002           # Initial noise amplitude
Nsteps = 50000          # Number of time steps
rng_seed = 12345        # RNG seed for reproducibility

# %%
cahn_hilliard(c0, M, kappa, W, noise, Nsteps, rng_seed)
# Out:
# Final mass = 0.500 ± 1.2e-07

# %% [raw]
# # === Optional: generate the GIF animation ===
#
# fig, ax = plt.subplots(1,1,figsize=(4,4))
# im = ax.imshow(c[0],cmap='bwr', vmin=0.0, vmax=1.0)
# cb = fig.colorbar(im,ax=ax, label=r'$c(x,y)$', shrink=0.8)
# tx = ax.text(190,20,'t={:.1f}'.format(0.0),
#          bbox=dict(boxstyle="round",ec='white',fc='white'))
# ax.set_title(r'$c_0=%.2f$'% c0)
#
# def animate(i):
#     im.set_data(c[5*i])
#     im.set_clim(0.0, 1.0)
#     tx.set_text('t={:.1f}'.format(5*i*dt))
#     return fig,
#
# ani = animation.FuncAnimation(fig, animate, frames= 199, interval = 50)
#
# # Save the GIF
# ani.save('c0_'+str(c0)+'.gif', writer='pillow', fps=20,dpi=150)
#
# # Display the GIF
# display(Image(filename="c0_'+str(c0)+'.gif"))

# %% [markdown]
# #### Task d
# Set $c_0 = 0.8$ while keeping all other parameters unchanged. You will notice that the concentration field does not evolve. Explain why this happens.
#
#
# #### Task e
# Try to fix the problem by adjusting the noise parameter. For which value of noise do you observe the nucleation of the secondary phase?

# %% [markdown]
# # c = 0.8

# %%
# === System-specific Parameters ===
c0 = 0.8                # Initial concentration
M = 0.5                 # Mobility
kappa = 0.6             # Gradient coefficient
W = 1.0                 # Bulk free energy strength
noise = 0.5           # Initial noise amplitude
Nsteps = 50000          # Number of time steps
rng_seed = 12345        # RNG seed for reproducibility

# %%
cahn_hilliard(c0, M, kappa, W, noise, Nsteps, rng_seed)
# Out:
# Final mass = 0.801 ± 0.0e+00
